# %% [markdown]
# # Exploratory Data Analysis notebook

# %%
import os
import sys
import pandas as pd
import numpy as np  
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
import warnings

# %%
seed = 0
np.random.seed(seed)

# %%
data_path = Path.cwd().parent / 'data' / 'Agricultural-crops'
data_path
# Out:
# WindowsPath('c:/Users/hongquan/Documents/GitHub/argi_crop_classification/data/Agricultural-crops')

# %%
file_path = []
labels = []

for folder in os.listdir(data_path):
    print(file)
    # if file.endswith('.csv'):
    #     file_path.append(os.path.join(data_path, file))
    #     labels.append(file.split('.')[0])
# Out:
# almond
# banana
# cardamom
# Cherry
# chilli
# clove
# coconut
# Coffee-plant
# cotton
# Cucumber
# Fox_nut(Makhana)
# gram
# jowar
# jute
# Lemon
# maize
# mustard-oil
# Olive-tree
# papaya
# Pearl_millet(bajra)
# pineapple
# rice
# soyabean
# sugarcane
# sunflower
# tea
# Tobacco-plant
# tomato
# vigna-radiati(Mung)
# wheat
